# %% [markdown]
# # View an individual TCGA record

# %% [markdown]
# In this notebook I view data I've downloaded from GDC, or TCGA, or something. I'm not sure what the site is called.
#
# I downloaded the data from https://portal.gdc.cancer.gov/files/4c713646-5364-40bb-b26a-0e2d48edd34d.

# %%
import pandas as pd

# %%
path = "/Users/william/Downloads/4c713646-5364-40bb-b26a-0e2d48edd34d/"\
       "jhu-usc.edu_BRCA.HumanMethylation27.3.lvl-3.TCGA-A1-A0SD-01A-11D-A112-05.gdc_hg38.txt"

# %%
pd.read_csv(path, sep="\t").sort_values("Gene_Symbol").reset_index().iloc[1000:]
# Out:
#        index Composite Element REF  Beta_value Chromosome      Start  \
# 1000    4049            cg04001333    0.619770      chr14   75579005
# 1001   14097            cg14125250    0.109053      chr19   18152780
# 1002   15904            cg15834294    0.026202      chr16   11915985
# 1003   25534            cg25537724    0.010875       chr2   39436641
# 1004    2709            cg02710105    0.009315       chr2   39437207
# ...      ...                   ...         ...        ...        ...
# 27573   2686            cg02678356         NaN       chrX   57910570
# 27574  24723            cg24762437    0.038706       chr1   77682919
# 27575   4179            cg04127303    0.018290       chr1   77682577
# 27576   9228            cg09288658    0.013219       chr2  173075911
# 27577   3633            cg03608974    0.031191       chr2  173075540
#
#              End                                        Gene_Symbol  \
# 1000    75579006                    AC007182.6;FLVCR2;FLVCR2;FLVCR2
# ...

# %%
pd.read_csv(path, sep="\t").sort_values("Gene_Symbol").loc
